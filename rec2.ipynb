# %%
import pandas as pd

# %%
df = pd.read_csv('Recbooklist.csv')
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                      10-Day Green Smoothie Cleanse
# 1             1                                  11/22/63: A Novel
# 2             2            12 Rules for Life: An Antidote to Chaos
# 3             3                             1984 (Signet Classics)
# 4             4  5,000 Awesome Facts (About Everything!) (Natio...
# ..          ...                                                ...
# 756         206                           Structure and Randomness
# 757         207                       Image Processing with MATLAB
# 758         208                                        Animal Farm
# 759         209                                         Idiot, The
# 760         210                                 Christmas Carol, A
#
#                        Author  Price        Genre
# 0                    JJ Smith      8  Non Fiction
# 1                Stephen King     22      Fiction
# ...

# %%
df.iloc[250:300]
# Out:
#      Unnamed: 0                                              Title  \
# 250         250                          Oh  the Places You'll Go!
# 251         251                          Oh  the Places You'll Go!
# 252         252                          Oh  the Places You'll Go!
# 253         253              Old School (Diary of a Wimpy Kid #10)
# 254         254                                   Olive Kitteridge
# 255         255  One Thousand Gifts: A Dare to Live Fully Right...
# 256         256  One Thousand Gifts: A Dare to Live Fully Right...
# 257         257  Option B: Facing Adversity  Building Resilienc...
# 258         258                   Origin: A Novel (Robert Langdon)
# 259         259                                       Orphan Train
# 260         260                     Outliers: The Story of Success
# 261         261                     Outliers: The Story of Success
# 262         262    P is for Potty! (Sesame Street) (Lift-the-Flap)
# ...

# %%
df = df[df['Author'].notna()]

# %%
df['Title'] = df['Title'].apply(lambda x: x.replace(',',' '))
# Out:
# <ipython-input-45-0cf118c79a9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Title'] = df['Title'].apply(lambda x: x.replace(',',' '))

# %%
df['Author'] = df['Author'].apply(lambda x: x.replace(',',' '))
# Out:
# <ipython-input-44-dbb7b0120bae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Author'] = df['Author'].apply(lambda x: x.replace(',',' '))

# %%
df = df[['Title', 'Author','Price', 'Genre']]
df
# Out:
#                                                  Title  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5 000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 756                           Structure and Randomness
# 757                       Image Processing with MATLAB
# 758                                        Animal Farm
# 759                                         Idiot  The
# 760                                 Christmas Carol  A
#
#                        Author  Price        Genre
# 0                    JJ Smith      8  Non Fiction
# 1                Stephen King     22      Fiction
# 2          Jordan B. Peterson     15  Non Fiction
# 3               George Orwell      6      Fiction
# ...

# %%
df.to_csv('newRecbooklist.csv')
